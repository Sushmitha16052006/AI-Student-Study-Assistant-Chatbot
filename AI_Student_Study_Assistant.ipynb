# %%
subjects = {
    "dbms": {
        "tips": [
            "Focus on normalization and SQL queries",
            "Practice ER diagrams",
            "Study previous year questions",
            "Understand indexing and transactions"
        ],
        "links": [
            "https://www.geeksforgeeks.org/dbms/",
            "https://www.javatpoint.com/dbms-tutorial",
            "https://www.youtube.com/watch?v=HXV3zeQKqGY"
        ]
    },

    "data structures": {
        "tips": [
            "Practice arrays, stacks, queues, and linked lists",
            "Understand time and space complexity",
            "Solve coding problems regularly",
            "Revise trees and graphs"
        ],
        "links": [
            "https://www.geeksforgeeks.org/data-structures/",
            "https://www.programiz.com/dsa",
            "https://www.youtube.com/watch?v=BBpAmxU_NQo"
        ]
    },

    "os": {
        "tips": [
            "Understand process scheduling algorithms",
            "Study deadlocks and memory management",
            "Practice numerical problems",
            "Focus on diagrams"
        ],
        "links": [
            "https://www.geeksforgeeks.org/operating-systems/",
            "https://www.javatpoint.com/operating-system",
            "https://www.youtube.com/watch?v=vBURTt97EkA"
        ]
    },

    "mac": {
        "tips": [
            "Understand instruction formats and addressing modes",
            "Study pipelining and RISC vs CISC",
            "Practice numerical problems",
            "Revise previous year questions"
        ],
        "links": [
            "https://www.geeksforgeeks.org/computer-organization-and-architecture-tutorials/",
            "https://www.javatpoint.com/computer-organization-and-architecture",
            "https://www.youtube.com/watch?v=DsK35f8wyUw"
        ]
    },

    "mfcs": {
        "tips": [
            "Practice set theory and relations",
            "Understand logic and proofs",
            "Revise recurrence relations",
            "Solve previous exam problems"
        ],
        "links": [
            "https://www.geeksforgeeks.org/mathematics-for-computer-science/",
            "https://www.tutorialspoint.com/discrete_mathematics",
            "https://www.youtube.com/watch?v=E1nGJz1y6Qs"
        ]
    },

    "daa": {
        "tips": [
            "Understand algorithm design techniques",
            "Practice time complexity analysis",
            "Revise greedy and dynamic programming algorithms",
            "Solve standard problems"
        ],
        "links": [
            "https://www.geeksforgeeks.org/design-and-analysis-of-algorithms/",
            "https://www.javatpoint.com/design-analysis-of-algorithms",
            "https://www.youtube.com/watch?v=0IAPZzGSbME"
        ]
    },

    "java": {
        "tips": [
            "Understand OOP concepts clearly",
            "Practice exception handling and collections",
            "Revise multithreading basics",
            "Write programs regularly"
        ],
        "links": [
            "https://www.geeksforgeeks.org/java/",
            "https://www.javatpoint.com/java-tutorial",
            "https://www.youtube.com/watch?v=grEKMHGYyns"
        ]
    },

    "python": {
        "tips": [
            "Practice syntax and built-in functions",
            "Understand lists, tuples, and dictionaries",
            "Solve coding problems",
            "Learn basic file handling"
        ],
        "links": [
            "https://www.geeksforgeeks.org/python-programming-language/",
            "https://www.programiz.com/python-programming",
            "https://www.youtube.com/watch?v=_uQrJ0TkZlc"
        ]
    }
}

user_input = input("Enter subject name: ").lower()

if user_input in subjects:
    print(f"\n📘 Study Strategy for {user_input.upper()}:\n")

    print("🔑 Important Tips:")
    for tip in subjects[user_input]["tips"]:
        print("✔", tip)

    print("\n🔗 Trusted Learning Resources:")
    for link in subjects[user_input]["links"]:
        print("🔗", link)
else:
    print("""
⚠️ Subject not supported yet.
This chatbot focuses on study strategies and learning guidance.

✔ Supported subjects:
- DBMS
- Data Structures
- Operating Systems
- MAC
- MFCS
- DAA
- Java
- Python
""")
# Out:
# Enter subject name: quit
#
# ⚠️ Subject not supported yet.
# This chatbot focuses on study strategies and learning guidance.
#
# ✔ Supported subjects:
# - DBMS
# - Data Structures
# - Operating Systems
# - MAC
# - MFCS
# - DAA
# - Java
# - Python
